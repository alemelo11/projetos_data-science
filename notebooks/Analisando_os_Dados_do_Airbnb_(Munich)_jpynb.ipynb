# %% [markdown]
# <a href="https://colab.research.google.com/github/alemelo11/Projetos_Data-Science/blob/main/Analisando_os_Dados_do_Airbnb_(Munich)_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise dos Dados do Airbnb - *Munich*
# ![munich-1572429_1280.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# O [Airbnb](https://www.airbnb.com.br/) já é considerado como sendo a **maior empresa hoteleira da atualidade**. Ah, o detalhe é que ele **não possui nenhum hotel**!
#
# Conectando pessoas que querem viajar (e se hospedar) com anfitriões que querem alugar seus imóveis de maneira prática, o Airbnb fornece uma plataforma inovadora para tornar essa hospedagem alternativa.
#
# No final de 2018, a Startup fundada 10 anos atrás, já havia **hospedado mais de 300 milhões** de pessoas ao redor de todo o mundo, desafiando as redes hoteleiras tradicionais.
#
#
#
# <center><img alt="Analisando Airbnb" width="10%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>
#
# **Neste *artigo*, iremos analisar os dados referentes à cidade de Munich, e ver quais insights podem ser extraídos a partir de dados brutos.**

# %% [markdown]
# ## Munich
#
# Capital do estado da Baviera, na Alemanha, e uma cidade conhecida por sua rica história, cultura vibrante e belas paisagens. Lar da famosa Oktoberfest, que atrai milhões de visitantes todos os anos, que vêm não só para celebrar a cerveja, mas também para explorar seus museus de classe mundial, arquitetura deslumbrante e parques exuberantes.
#
# O turismo desempenha um papel significativo na economia de Munich, contribuindo não apenas para o setor de hospitalidade, mas também para o comércio, gastronomia e entretenimento. A cidade recebe uma ampla gama de turistas, desde viajantes interessados ​​em história e arte até entusiastas da natureza que desfrutam dos Alpes Bávaros próximos.

# %% [markdown]
# *Relação entre o Setor Hoteleiro e o Airbnb*:
#
# Assim como em muitas outras cidades ao redor do mundo, o surgimento do Airbnb em Munique trouxe mudanças significativas para o setor hoteleiro. Enquanto os hotéis tradicionais continuam a ser uma opção popular para muitos turistas, o Airbnb oferece uma alternativa única, permitindo que os visitantes experimentem a cidade de uma maneira mais local, muitas vezes ficando em bairros residenciais e interagindo diretamente com os moradores locais.
#
# Essa competição entre hotéis e acomodações do Airbnb pode ter impactos variados, desde uma maior diversidade de opções de hospedagem para os turistas até desafios para o setor hoteleiro tradicional em termos de manutenção da competitividade e ocupação.
#
# *Regulamentações e Questões Legais*:
#
# No que diz respeito às regulamentações, Munique implementou medidas específicas para regulamentar o aluguel de curto prazo por meio de plataformas como o Airbnb. Estas podem incluir restrições quanto ao número de dias que uma propriedade pode ser alugada por ano, impostos sobre estadias curtas e requisitos de registro para proprietários de Airbnb.
#
# Além disso, as autoridades locais podem estar monitorando de perto o impacto do Airbnb no mercado imobiliário e na comunidade local, procurando equilibrar os benefícios do turismo com as preocupações sobre o aumento dos preços dos aluguéis e a gentrificação.

# %% [markdown]
# ## Obtenção dos Dados
# Os dados utilizados neste *notebook* foram obtidos por meio do site [Inside Airbnb](http://insideairbnb.com/get-the-data.html).
#
# Para análise exploratório foi baixado apenas o arquivo `listings.csv`- *Summary information and metrics for listings in Munich (good for visualisations).*

# %%
# importar os pacotes necessarios
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display


# %matplotlib inline

# %% [markdown]
# ## Análise dos Dados
# Nesta etapa, o objetivo é garantir um entendimento de como os dados estão estruturados, assim você terá um melhor entendimento da análise. Portanto, será apresentado um dicionário a respeito de cada uma das variáveis.

# %% [markdown]
# **Dicionário das variáveis**
#
# * `id` - número de id gerado para identificar o imóvel
# * `name` - nome da propriedade anunciada
# * `host_id` - número de id do proprietário (anfitrião) da propriedade
# * `host_name` - Nome do anfitrião
# * `neighbourhood_group` - esta coluna não contém nenhum valor válido
# * `neighbourhood` - nome do bairro
# * `latitude` - coordenada da latitude da propriedade
# * `longitude` - coordenada da longitude da propriedade
# * `room_type` - informa o tipo de quarto que é oferecido
# * `price` - preço para alugar o imóvel
# * `minimum_nights` - quantidade mínima de noites para reservar
# * `number_of_reviews` - número de reviews que a propriedade possui
# * `last_review` - data do último review
# * `reviews_per_month` - quantidade de reviews por mês
# * `calculated_host_listings_count` - quantidade de imóveis do mesmo anfitrião
# * `availability_365` - número de dias de disponibilidade dentro de 365 dias
# * `number_of_reviews_ltm` - número de reviews dos últimos doze meses
# * `license` - licença ou permissão necessária para alugar uma propriedade de forma legal

# %% [markdown]
#   Vamos começar analisando as 5 primeiras entradas, dessa forma vamos conhecer o nosso dataset e assim caminharemos para uma análise mais profunda.

# %% [markdown]
# ### **Q1. Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais os tipos das variáveis?**
#
# Com algumas linhas de código, é possível notar a presença de 18 variáveis e 6555 entradas, sendo algumas delas dos tipos, inteiro, float e objeto.

# %%
# importar o arquivo listings.csv para um DataFrame
df= pd.read_csv("http://data.insideairbnb.com/germany/bv/munich/2023-12-26/visualisations/listings.csv")

# identificar o volume de dados do DataFrame
print(f"Dimensões do Dataset \n Entradas:\t {df.shape[0]}")
print(f"Variáveis:\t {df.shape[1]}")

# mostrar as 5 primeiras entradas
df.head()
# Out:
# Dimensões do Dataset
#  Entradas:	 6555
# Variáveis:	 18
#        id                                               name  host_id  \
# 0   97945  Rental unit in Munich · ★4.84 · 1 bedroom · 1 ...   517685
# 1  114695  Rental unit in Munich · ★4.82 · 1 bedroom · 1 ...   581737
# 2  127383  Rental unit in Munich · ★4.83 · 1 bedroom · 1 ...   630556
# 3  159634  Rental unit in Munich · ★4.63 · 1 bedroom · 1 ...   765694
# 4  170154  Home in Munich · ★4.96 · 1 bedroom · 2 beds · ...   108297
#
#   host_name  neighbourhood_group       neighbourhood  latitude  longitude  \
# 0  Angelika                  NaN              Hadern  48.11492   11.48954
# 1   Stephan                  NaN        Berg am Laim  48.12071   11.63758
# 2     Sonja                  NaN         Maxvorstadt  48.15199   11.56482
# 3    Susana                  NaN  Pasing-Obermenzing  48.13855   11.46586
# 4      Alex                  NaN   Sendling-Westpark  48.10814   11.52733
#
# ...

# %%
# verificar aos tipos
display(df.dtypes)
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                             float64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# ### **Q2. Há valores ausentes no *dataset*? Qual a porcentagem?**
#
#  A qualidade de um dataset está diretamente relacionada à quantidade de valores ausentes. É importante entender logo no início se esses valores nulos são significativos comparados ao total de entradas.
#
# * Na coluna `neighbourhood_group` é possível notar que 100% dos valores não foram inseridos
# * Aproximadamente 20% dos valores das variáveis `price`, `reviews_per_month` e `last_review` são nulos

# %%
# verificando dados ausentes
(df.isnull().sum()).sort_values(ascending=False)
# Out:
# neighbourhood_group               6555
# license                           6535
# price                             1447
# last_review                       1314
# reviews_per_month                 1314
# host_name                            1
# host_id                              0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# name                                 0
# minimum_nights                       0
# number_of_reviews                    0
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# id                                   0
# dtype: int64

# %%
# ordenar em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# neighbourhood_group               1.000000
# license                           0.996949
# price                             0.220748
# last_review                       0.200458
# reviews_per_month                 0.200458
# host_name                         0.000153
# host_id                           0.000000
# neighbourhood                     0.000000
# latitude                          0.000000
# longitude                         0.000000
# room_type                         0.000000
# name                              0.000000
# minimum_nights                    0.000000
# number_of_reviews                 0.000000
# calculated_host_listings_count    0.000000
# availability_365                  0.000000
# number_of_reviews_ltm             0.000000
# id                                0.000000
# dtype: float64

# %% [markdown]
# ### **Q3. Qual o tipo de distribuição das variáveis?**
#
# Para termos uma melhor visualização a respeito da distribuição das variáveis, irei plotar um histograma.

# %%
# plotar o histograma das variáveis numéricas
df.hist(bins=15, figsize=(15,10), grid=False);

# %% [markdown]
# ### **Q4. Há *outliers* presentes?**

# %%
# ver o resumo estatístico das variáveis numéricas
df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count   5108.000000     6555.000000        6555.000000        5241.000000
# mean     191.036022        8.102975          24.609916           0.994585
# std     1369.675817       29.322535          70.913430           1.614333
# min        9.000000        1.000000           0.000000           0.010000
# 25%       77.000000        1.000000           1.000000           0.200000
# 50%      112.000000        2.000000           5.000000           0.490000
# 75%      190.000000        4.000000          17.000000           1.190000
# max    96274.000000      999.000000        1749.000000          53.760000
#
#        calculated_host_listings_count  availability_365
# count                     6555.000000       6555.000000
# mean                         3.159573        112.971167
# std                          8.791147        125.111470
# min                          1.000000          0.000000
# ...

# %% [markdown]
# Olhando o resumo estatístico acima, podemos confirmar algumas hipóteses como a presença de outliers:
#
# * A variável `price` possui 75% (Q3) do valor abaixo de 190€, porém seu valor máximo é 96274€.
# * O valor máximo para a variável `minimum_nights` está acima de 365 dias no ano.
#
#
#  Para tratá-los vamos seguir os seguintes passos:
#
# * Definir o Q1 e Q3 para as variáveis que serão limpas.
# * Calcular o IQR para as variáveis.
# * Definir o limite superior e inferior para cortar os outliers.
# * Remover os outliers.

# %% [markdown]
# #### **Definindo limites para 'Price'**

# %%
# identificando os outliers para a variável price
q1_price = df.price.quantile(.25)
q3_price = df.price.quantile(.75)
IQR_price = q3_price - q1_price
print('IQR da variável price: ', IQR_price)

# definindo os limites
sup_price = q3_price + 1.5 * IQR_price
inf_price = q1_price - 1.5 * IQR_price

print('Limite superior de price: ', sup_price)
print('Limite inferior de price: ', inf_price)
# Out:
# IQR da variável price:  113.0
# Limite superior de price:  359.5
# Limite inferior de price:  -92.5

# %% [markdown]
# #### **Boxplot para price**

# %%
# price
df.price.plot(kind='box', vert=False, figsize=(15, 3))
plt.show()

# ver quantidade de valores acima de 240 para price
print('\nprice: valores acima de 359.5')
print(f'{len(df[df.price > 359.5])} entradas')
print(f'{(len(df[df.price > 359.5]) / df.shape[0])*100:.4f}%')
# Out:
# price: valores acima de 359.5
# 429 entradas
# 6.5446%

# %% [markdown]
# Alguns insights tirados dessa análise :
#
# * Existem aproximadamente 222 entradas de acomodações com valores acima de 359.5 euros
# * E essas acomodações representam apenas 6.54% do *dataset*

# %% [markdown]
# #### **Definindo limites para 'minimum_nights'**

# %%
q1_minimum_nights = df.minimum_nights.quantile(.25)
q3_minimum_nights = df.minimum_nights.quantile(.75)
IQR_minimum_nights = q3_minimum_nights - q1_minimum_nights
print('IQR da variável minimum_nights: ', IQR_minimum_nights)

# definindo os limites
sup_minimum_nights = q3_minimum_nights + 1.5 * IQR_minimum_nights
inf_minimum_nights = q1_minimum_nights - 1.5 * IQR_minimum_nights

print('Limite superior de minimum_nigths: ', sup_minimum_nights)
print('Limite inferios de minimum_nigths: ', inf_minimum_nights)
# Out:
# IQR da variável minimum_nights:  3.0
# Limite superior de minimum_nigths:  8.5
# Limite inferios de minimum_nigths:  -3.5

# %% [markdown]
# #### **Boxplot para minimum_nights**

# %%
# minimum_nights
df.minimum_nights.plot(kind='box', vert=False, figsize=(15, 3))
plt.show()


# Ver quantidade de valores acima de 30 dias para minimum_nights
valores_acima_de_9 = len(df[df.minimum_nights > 9])
total_entradas = df.shape[0]

print(f"minimum_nights: valores acima de 9:")
print(f"{valores_acima_de_9} entradas")
print(f"{(valores_acima_de_9 / total_entradas) * 100:.4f}%")
# Out:
# minimum_nights: valores acima de 9:
# 796 entradas
# 12.1434%

# %% [markdown]
# #### Histogramas sem *outliers*
#
# Já que identificamos *outliers* nas variáveis `price` e `minimum_nights`, vamos agora limpar o *DataFrame* delas e plotar novamente o histograma.

# %%
# remover os *outliers* em um novo DataFrame
df_clean = df.copy()
df_clean.drop(df_clean[df_clean.price > 359.5].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.minimum_nights > 8].index, axis=0, inplace=True)

# remover `neighbourhood_group`, pois está vazio
df_clean.drop('neighbourhood_group', axis=1, inplace=True)

# plotar o histograma para as variáveis numéricas
df_clean.hist(bins=15, figsize=(15,10), grid=False);

# %% [markdown]
# ### **Q4. Qual a média dos preços de aluguel?**

# %%
# ver a média da coluna `price``
df.price.mean()
# Out:
# 191.03602192638996

# %% [markdown]
# ### **Q4. Qual a correlação existente entre as variáveis**
#
# Correlação significa que existe uma relação entre duas coisas. No nosso contexto, estamos buscando relação ou semelhança entre duas variáveis.
#
# Essa relação pode ser medida, e é função do coeficiente de correlação estabelecer qual a intensidade dela. Para identificar as correlações existentes entre as variáveis de interesse, vou:
#
# * Criar uma matriz de correlação
# * Gerar um *heatmap* a partir dessa matriz, usando a biblioteca `seaborn`

# %%
# criar uma matriz de correlação
corr = df_clean[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].corr()

# mostrar a matriz de correlação
display(corr)
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.039557          -0.084140
# minimum_nights                 -0.039557        1.000000          -0.101794
# number_of_reviews              -0.084140       -0.101794           1.000000
# reviews_per_month              -0.073024       -0.196725           0.656128
# calculated_host_listings_count -0.029368        0.138050          -0.002570
# availability_365                0.152741       -0.126823           0.025369
#
#                                 reviews_per_month  \
# price                                   -0.073024
# minimum_nights                          -0.196725
# number_of_reviews                        0.656128
# reviews_per_month                        1.000000
# calculated_host_listings_count          -0.007226
# availability_365                         0.075003
#
#                                 calculated_host_listings_count  \
# ...

# %%
# plotar um heatmap a partir das correlações
sns.heatmap(corr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True);

# %% [markdown]
# ### **Q5. Qual o tipo de imóvel mais alugado no Airbnb?**
#
# A coluna da variável room_type indica o tipo de locação que está anunciada no Airbnb. Se você já alugou no site, sabe que existem opções de apartamentos/casas inteiras, apenas o aluguel de um quarto ou mesmo dividir o quarto com outras pessoas.
#
# Vamos contar a quantidade de ocorrências de cada tipo de aluguel, usando o método value_counts().

# %%
# mostrar a quantidade de cada tipo de imóvel disponível
df_clean.room_type.value_counts()
# Out:
# Entire home/apt    3371
# Private room       1931
# Shared room          53
# Hotel room           20
# Name: room_type, dtype: int64

# %%
# mostrar a porcentagem de cada tipo de imóvel disponível
df_clean.room_type.value_counts() / df_clean.shape[0]
# Out:
# Entire home/apt    0.627163
# Private room       0.359256
# Shared room        0.009860
# Hotel room         0.003721
# Name: room_type, dtype: float64

# %% [markdown]
# Os imóveis tem uma distribuição bem interessante, veja:
#
#  Casas/apt inteiros e Quartos privados ocupam cerca de 98% dos imóveis anunciados
# E menos de 1% são Quartos compartilhados

# %% [markdown]
# ### **Q6. Qual a localidade mais cara de Munich?**
#
# Uma maneira de se verificar uma variável em função da outra é usando `groupby()`. No caso, queremos comparar os bairros (*neighbourhoods*) a partir do preço de locação.

# %%
# ver preços por bairros, na média
df_clean.groupby(['neighbourhood']).price.mean().sort_values(ascending=False)[:10]
# Out:
# neighbourhood
# Altstadt-Lehel                  176.803030
# Ludwigsvorstadt-Isarvorstadt    163.759596
# Schwanthalerhöhe                160.637795
# Maxvorstadt                     143.360606
# Sendling                        135.368794
# Schwabing-Freimann              134.403061
# Au-Haidhausen                   131.684874
# Schwabing-West                  127.902222
# Neuhausen-Nymphenburg           127.813278
# Bogenhausen                     127.361809
# Name: price, dtype: float64

# %% [markdown]
# O bairro mais caro é `Altstadt-Lehel` seguido por `Ludwigsvorstadt-Isarvorstad`, ambos na região central da cidade

# %%
# plotar os imóveis pela latitude-longitude
df_clean.plot(kind="scatter", x='longitude', y='latitude', alpha=0.4, c=df_clean['price'], s=8,
              cmap=plt.get_cmap('jet'), figsize=(12,8));

# %% [markdown]
# ### **Q7. Qual é a média do mínimo de noites para aluguel (minimum_nights)?**

# %%
# ver a média da coluna `minimum_nights``
df.minimum_nights.mean()
# Out:
# 8.102974828375286

# %% [markdown]
# ## Conclusões
# Neste projeto, conseguimos tirar algumas informações sobre o Airbnb na cidade de Munich.
# A média de preço é de 191,036 euros.
#
# Algumas outras informações:
#
# Cerca de 63% dos anúncios são apenas de Casas/apt inteiros (`Entire home/apt`)
#
# A média de preços mais cara é a de `Altstadt-Lehel` seguido de `Ludwigsvorstadt-Isarvorstadt`
#
# A média de `minimum_nights` é cerca de 8 noites, geralmente para que os hóspedes aluguem ao menos por uma semana.
